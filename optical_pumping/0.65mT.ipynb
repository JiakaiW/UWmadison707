# %%
name = '0.65mT.CSV'

# %%
import csv
with open(name, newline='\n') as csvfile:
    reader = csv.DictReader(csvfile)
    for i,row in enumerate(reader):
        print(row)
        if i > 13:
            break
# Out:
# {'Model': 'Firmware Version', 'TBS2104': 'v1.26.0'}
# {'Model': 'Point Format', 'TBS2104': 'Y'}
# {'Model': 'Horizontal Units', 'TBS2104': 'S'}
# {'Model': 'Horizontal Scale', 'TBS2104': '0.02'}
# {'Model': 'Sample Interval', 'TBS2104': '0.00016'}
# {'Model': 'Filter Frequency', 'TBS2104': '1e+08'}
# {'Model': 'Record Length', 'TBS2104': '2000'}
# {'Model': 'Gating', 'TBS2104': '0.0% to 100.0%'}
# {'Model': 'Probe Attenuation', 'TBS2104': '10'}
# {'Model': 'Vertical Units', 'TBS2104': 'V'}
# {'Model': 'Vertical Offset', 'TBS2104': '0'}
# {'Model': 'Vertical Scale', 'TBS2104': '0.05'}
# {'Model': 'Label', 'TBS2104': ''}
# {'Model': 'TIME', 'TBS2104': 'CH2'}
# {'Model': '-1.338e-01', 'TBS2104': '0.013623'}

# %%
import csv

x = []
y = []
with open(name, newline='\n') as csvfile:
    reader = csv.DictReader(csvfile)
    for i,row in enumerate(reader):
        if i >= 14:
            x.append(row['Model']) 
            y.append(row['TBS2104'])

# %%
import numpy as np

x = np.array(x,dtype=float)
y = np.array(y,dtype=float)

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,1)

axes[0].plot(x)
axes[1].plot(y)

# %%
fig,axes = plt.subplots(2,1)

axes[0].plot(y)
axes[0].set_xlim(250,500)
axes[0].set_ylim(0,0.025)


axes[1].plot(y)
axes[1].set_xlim(1500,1750)
axes[1].set_ylim(0,0.025)
# Out:
# (0.0, 0.025)

# %%
start_idx = 330
stop_idx = 1640
x_trunc = x[start_idx:stop_idx]
y_trunc = y[start_idx:stop_idx]

# %%
stop_idx - start_idx
# Out:
# 1310

# %%
freq_start = 20
freq_stop = 1002

# %%
freq = np.arange(len(x_trunc))
freq = freq * (freq_stop-freq_start)/len(freq) + freq_start

plt.plot(freq)
plt.xlabel('idx')
plt.ylabel('KHz')
# Out:
# Text(0, 0.5, 'KHz')

# %%
plt.plot(freq,y_trunc)
plt.title('Measured 0.65 mT')
plt.xlabel('KHz')
plt.ylabel('response')
# Out:
# Text(0, 0.5, 'response')
